# %% [markdown]
# <a href="https://colab.research.google.com/github/ArkS0001/RAG/blob/main/RAG_Memory_Hallucination.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Memorization:** The LSTM accurately reproduces sequences it has seen in training.
# **Hallucination:** The LSTM generates plausible but novel sequences when given unseen or incomplete inputs.

# %%
import numpy as np
import random
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer

# Step 1: Generate Synthetic Data (Memorization and Hallucination)
# Generate sequences of symbolic data
symbols = ["A", "B", "C", "D", "E"]
patterns = [
    "A B C D",  # Common sequence 1
    "B C D E",  # Common sequence 2
    "A E D C",  # Common sequence 3
    "C B A E",  # Rare sequence
]

# Augment data with variations and noise
def generate_synthetic_data(patterns, num_samples=1000):
    data = []
    for _ in range(num_samples):
        pattern = random.choice(patterns)
        # Introduce random hallucination or noise
        if random.random() > 0.8:  # 20% chance of hallucination
            hallucination = random.choices(symbols, k=random.randint(3, 5))
            data.append(" ".join(hallucination))
        else:
            data.append(pattern)
    return data

synthetic_data = generate_synthetic_data(patterns)

# Step 2: Preprocess Data
# Tokenize the data
tokenizer = Tokenizer()
tokenizer.fit_on_texts(synthetic_data)
vocab_size = len(tokenizer.word_index) + 1

# Convert to sequences
sequences = tokenizer.texts_to_sequences(synthetic_data)

# Pad sequences
max_sequence_len = max(len(seq) for seq in sequences)
sequences = pad_sequences(sequences, maxlen=max_sequence_len, padding="post")

# Create predictors (X) and labels (y)
X, y = sequences[:, :-1], sequences[:, -1]
y = np.eye(vocab_size)[y]

# Step 3: Build the LSTM Model
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=50, input_length=max_sequence_len - 1),
    LSTM(150, return_sequences=False),
    Dense(100, activation="relu"),
    Dense(vocab_size, activation="softmax")
])

model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Step 4: Train the Model
model.fit(X, y, epochs=50, batch_size=32, verbose=1)

# Step 5: Evaluate Memorization and Hallucination
# Generate new sequences based on a seed text
def generate_sequence(seed_text, next_words=5):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len - 1, padding="post")
        predicted = np.argmax(model.predict(token_list), axis=-1)[0]
        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted:
                output_word = word
                break
        seed_text += " " + output_word
    return seed_text

# Example Usage
seed_text = "A B C"
generated_sequence = generate_sequence(seed_text)
print("Seed Text:", seed_text)
print("Generated Sequence:", generated_sequence)

# Evaluate memorization by providing common sequences
test_sequences = ["A B C D", "B C D E", "A E D C"]
for seq in test_sequences:
    print(f"Input: {seq} \nGenerated: {generate_sequence(seq)}\n")

# Evaluate hallucination by providing incomplete or unseen sequences
hallucination_tests = ["E A", "D C", "B E"]
for seq in hallucination_tests:
    print(f"Input: {seq} \nHallucinated: {generate_sequence(seq)}\n")
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8098 - loss: 1.4074
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9201 - loss: 0.4345
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9320 - loss: 0.3495
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9353 - loss: 0.3331
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9299 - loss: 0.3570
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9365 - loss: 0.3078
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9241 - loss: 0.3491
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9250 - loss: 0.3442
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9178 - loss: 0.3549
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9329 - loss: 0.2986
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9308 - loss: 0.3006
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9125 - loss: 0.3588
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9367 - loss: 0.2763
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9208 - loss: 0.2907
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9309 - loss: 0.2599
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9349 - loss: 0.2521
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9311 - loss: 0.2578
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9249 - loss: 0.2595
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9269 - loss: 0.2475
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9364 - loss: 0.2153
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9281 - loss: 0.2152
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9293 - loss: 0.2325
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9316 - loss: 0.2137
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9357 - loss: 0.2138
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9274 - loss: 0.2036
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9370 - loss: 0.2062
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9397 - loss: 0.1996
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9303 - loss: 0.2254
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9418 - loss: 0.1701
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9282 - loss: 0.1911
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9257 - loss: 0.2124
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9400 - loss: 0.1591
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9394 - loss: 0.1623
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9433 - loss: 0.1506
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9550 - loss: 0.1298
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9381 - loss: 0.1679
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9523 - loss: 0.1295
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9466 - loss: 0.1389
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9446 - loss: 0.1458
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9509 - loss: 0.1336
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9438 - loss: 0.1485
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9579 - loss: 0.1222
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9660 - loss: 0.0931
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9623 - loss: 0.0990
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9705 - loss: 0.0926
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9778 - loss: 0.0813
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9805 - loss: 0.0659
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9789 - loss: 0.0638
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9715 - loss: 0.0860
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9806 - loss: 0.0577
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Seed Text: A B C
# Generated Sequence: A B C
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Input: A B C D
# Generated: A B C D
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Input: B C D E
# Generated: B C D E
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Input: A E D C
# Generated: A E D C
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Input: E A
# Hallucinated: E A
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Input: D C
# Hallucinated: D C
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Input: B E
# Hallucinated: B E

# %% [markdown]
# 1. Generate Synthetic Data:
#
#     The code starts by defining a set of symbolic patterns and generates synthetic data by choosing patterns at random.
#     Occasionally (20% of the time), a "hallucination" (random noise) is introduced, which deviates from the normal patterns. This simulates the model's tendency to hallucinate when it sees unfamiliar sequences.
#
# 2. Preprocess Data:
#
#     Tokenization: The Tokenizer class is used to assign a unique integer to each word in the dataset.
#     Padding: Sequences are padded so that all input sequences have the same length, ensuring consistency in LSTM input.
#     Prepare Inputs and Labels: The sequences are split into predictors (X) and labels (y). The labels are one-hot encoded to fit the categorical nature of the output (a classification problem where each word is treated as a separate class).
#
# 3. Build the LSTM Model:
#
#     The model is built with an Embedding layer to map words into a dense vector space, an LSTM layer to capture sequential dependencies, and Dense layers to predict the next word based on the learned patterns.
#     The final layer uses a softmax activation function, which outputs a probability distribution over all possible words, and the model is trained using categorical cross-entropy as the loss function.
#
# 4. Train the Model:
#
#     The model is trained on the synthetic data for 50 epochs, using a batch size of 32.
#
# 5. Evaluate Memorization and Hallucination:
#
#     Memorization: By providing common patterns, the model is expected to accurately predict the continuation of these sequences.
#     Hallucination: For unseen or incomplete sequences, the model might generate unexpected outputs or hallucinate words that deviate from the known patterns.
#
# Example Test:
#
#     The code then demonstrates the model's ability to generate sequences based on a seed text, and it shows how the model performs with both familiar patterns and rare or hallucinated sequences.
#
# Improvements/Considerations:
#
#     Data Augmentation: You could add more variations or increase the data size to improve generalization.
#     Model Evaluation: To properly evaluate the model's performance on memorization and hallucination, a more structured evaluation (e.g., using perplexity, accuracy on unseen sequences) can be added.
#     Hallucination Handling: You could adjust the model to handle hallucinations more effectively by introducing regularization or refining the training data.

# %%
import numpy as np
import random
from tensorflow.keras.models import Model
from tensorflow.keras.layers import LSTM, Dense, Embedding, Bidirectional, Input, Attention, LayerNormalization
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.optimizers import Adam

# Step 1: Generate Complex Synthetic Data (Memorization and Hallucination)
sentences = [
    "The quick brown fox jumps over the lazy dog",
    "Hello, how are you today?",
    "I am learning natural language processing",
    "This is a test sentence for sequence generation",
    "AI models are improving everyday with new architectures"
]
# Augment data with variations and noise (hallucinations)
def generate_synthetic_data(sentences, num_samples=1000):
    data = []
    for _ in range(num_samples):
        sentence = random.choice(sentences)
        # Introduce random hallucination or noise
        if random.random() > 0.8:  # 20% chance of hallucination
            hallucination = random.choices(["hello", "quick", "AI", "learning", "models"], k=random.randint(1, 4))
            data.append(" ".join(hallucination))
        else:
            data.append(sentence)
    return data

synthetic_data = generate_synthetic_data(sentences)

# Step 2: Preprocess Data
tokenizer = Tokenizer()
tokenizer.fit_on_texts(synthetic_data)
vocab_size = len(tokenizer.word_index) + 1

sequences = tokenizer.texts_to_sequences(synthetic_data)

max_sequence_len = max(len(seq) for seq in sequences)
sequences = pad_sequences(sequences, maxlen=max_sequence_len, padding="post")

X, y = sequences[:, :-1], sequences[:, -1]
y = np.eye(vocab_size)[y]

# Step 3: Build a More Complex Model with BiLSTM and Attention
input_seq = Input(shape=(max_sequence_len - 1,))
embedding = Embedding(input_dim=vocab_size, output_dim=50, input_length=max_sequence_len - 1)(input_seq)
bi_lstm = Bidirectional(LSTM(150, return_sequences=True))(embedding)

# Apply Attention mechanism
attention = Attention()([bi_lstm, bi_lstm])
attention_output = LayerNormalization()(attention)
lstm_out = LSTM(150)(attention_output)

# Dense layers and output
dense_1 = Dense(100, activation="relu")(lstm_out)
output = Dense(vocab_size, activation="softmax")(dense_1)

# Create and compile model
model = Model(inputs=input_seq, outputs=output)
model.compile(optimizer=Adam(), loss="categorical_crossentropy", metrics=["accuracy"])

# Step 4: Train the Model
model.fit(X, y, epochs=50, batch_size=32, verbose=1)

# Step 5: Generate Sequences
def generate_sequence(seed_text, next_words=5):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len - 1, padding="post")
        predicted = np.argmax(model.predict(token_list), axis=-1)[0]
        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted:
                output_word = word
                break
        seed_text += " " + output_word
    return seed_text

# Example Usage
seed_text = "The quick brown"
generated_sequence = generate_sequence(seed_text)
print("Seed Text:", seed_text)
print("Generated Sequence:", generated_sequence)

# Evaluate memorization by providing common sequences
test_sequences = ["The quick brown fox", "I am learning natural", "AI models are"]
for seq in test_sequences:
    print(f"Input: {seq} \nGenerated: {generate_sequence(seq)}\n")

# Evaluate hallucination by providing incomplete or unseen sequences
hallucination_tests = ["Hello world", "Natural language", "AI systems"]
for seq in hallucination_tests:
    print(f"Input: {seq} \nHallucinated: {generate_sequence(seq)}\n")
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 72ms/step - accuracy: 0.8453 - loss: 1.2951
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 1.0000 - loss: 7.1084e-05
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 1.0000 - loss: 2.6733e-05
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 130ms/step - accuracy: 1.0000 - loss: 2.2997e-05
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 1.0000 - loss: 2.0797e-05
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 1.0000 - loss: 2.0255e-05
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 1.0000 - loss: 1.7926e-05
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 1.0000 - loss: 1.6433e-05
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 1.0000 - loss: 1.7415e-05
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 1.5700e-05
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 1.0000 - loss: 1.4240e-05
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 1.0000 - loss: 1.3337e-05
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 1.0000 - loss: 1.2458e-05
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 1.0000 - loss: 1.1849e-05
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 1.0000 - loss: 1.1007e-05
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 1.0000 - loss: 1.0408e-05
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 1.0000 - loss: 9.6631e-06
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - accuracy: 1.0000 - loss: 9.1500e-06
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - accuracy: 1.0000 - loss: 8.3942e-06
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 1.0000 - loss: 8.0503e-06
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - accuracy: 1.0000 - loss: 7.5271e-06
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 1.0000 - loss: 7.2668e-06
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 1.0000 - loss: 6.5509e-06
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 1.0000 - loss: 6.2410e-06
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 1.0000 - loss: 6.0097e-06
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 1.0000 - loss: 5.8026e-06
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 1.0000 - loss: 5.5007e-06
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 1.0000 - loss: 5.2552e-06
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 1.0000 - loss: 5.0286e-06
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 1.0000 - loss: 4.7556e-06
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 1.0000 - loss: 4.5124e-06
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 1.0000 - loss: 4.3562e-06
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 1.0000 - loss: 4.0568e-06
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 133ms/step - accuracy: 1.0000 - loss: 4.0436e-06
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 1.0000 - loss: 3.7998e-06
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - accuracy: 1.0000 - loss: 3.6252e-06
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 1.0000 - loss: 3.4029e-06
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - accuracy: 1.0000 - loss: 3.2795e-06
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 1.0000 - loss: 3.0758e-06
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 1.0000 - loss: 3.0667e-06
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 1.0000 - loss: 2.9397e-06
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 1.0000 - loss: 2.8537e-06
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 1.0000 - loss: 2.7375e-06
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 1.0000 - loss: 2.5507e-06
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 1.0000 - loss: 2.4971e-06
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 1.0000 - loss: 2.2784e-06
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - accuracy: 1.0000 - loss: 2.2228e-06
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 1.0000 - loss: 2.1477e-06
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 1.0000 - loss: 2.1913e-06
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 1.0000 - loss: 2.0945e-06
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Seed Text: The quick brown
# Generated Sequence: The quick brown
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Input: The quick brown fox
# Generated: The quick brown fox
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Input: I am learning natural
# Generated: I am learning natural
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Input: AI models are
# Generated: AI models are
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Input: Hello world
# Hallucinated: Hello world
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Input: Natural language
# Hallucinated: Natural language
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Input: AI systems
# Hallucinated: AI systems

# %%
import numpy as np
import random
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer

# Step 1: Generate Synthetic Data (Memorization and Hallucination)
# Generate sequences of sentences
patterns = [
    "The quick brown fox jumped over the lazy dog",
    "I am learning natural language processing",
    "Artificial intelligence is transforming industries",
    "Deep learning models are very powerful",
    "Natural language understanding is a key aspect of AI",
    "The quick brown fox is a classic typing test sentence",
    "Machine learning enables data-driven decisions",
]

# Augment data with variations and noise
def generate_synthetic_data(patterns, num_samples=1000):
    data = []
    for _ in range(num_samples):
        pattern = random.choice(patterns)
        # Introduce random hallucination or noise (random sentence fragments)
        if random.random() > 0.8:  # 20% chance of hallucination
            hallucination = random.choices(patterns, k=random.randint(1, 3))
            data.append(" ".join(hallucination))
        else:
            data.append(pattern)
    return data

synthetic_data = generate_synthetic_data(patterns)

# Step 2: Preprocess Data
# Tokenize the data
tokenizer = Tokenizer()
tokenizer.fit_on_texts(synthetic_data)
vocab_size = len(tokenizer.word_index) + 1

# Convert to sequences
sequences = tokenizer.texts_to_sequences(synthetic_data)

# Pad sequences
max_sequence_len = max(len(seq) for seq in sequences)
sequences = pad_sequences(sequences, maxlen=max_sequence_len, padding="post")

# Create predictors (X) and labels (y)
X, y = sequences[:, :-1], sequences[:, -1]
y = np.eye(vocab_size)[y]

# Step 3: Build the LSTM Model
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=50, input_length=max_sequence_len - 1),
    LSTM(150, return_sequences=False),
    Dense(100, activation="relu"),
    Dense(vocab_size, activation="softmax")
])

model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Step 4: Train the Model
model.fit(X, y, epochs=50, batch_size=32, verbose=1)

# Step 5: Generate Sequences with Sampling (Temperature)
def generate_sequence_with_sampling(seed_text, next_words=5, temperature=1.0):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len - 1, padding="post")

        # Predict probabilities
        predictions = model.predict(token_list)[0]

        # Adjust probabilities based on temperature
        predictions = np.asarray(predictions).astype("float64")
        predictions = np.log(predictions + 1e-7) / temperature
        predictions = np.exp(predictions) / np.sum(np.exp(predictions))  # Softmax

        # Sample from the predicted distribution
        predicted = np.random.choice(range(vocab_size), p=predictions)

        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted:
                output_word = word
                break

        seed_text += " " + output_word

    return seed_text

# Example Usage with Sampling:
seed_text = "The quick brown fox"
generated_sequence = generate_sequence_with_sampling(seed_text, temperature=0.8)
print("Generated Sequence:", generated_sequence)

# Evaluate memorization by providing common sequences
test_sequences = [
    "The quick brown fox jumped over the lazy dog",
    "I am learning natural language processing",
    "Artificial intelligence is transforming industries"
]
for seq in test_sequences:
    print(f"Input: {seq} \nGenerated: {generate_sequence_with_sampling(seq)}\n")

# Evaluate hallucination by providing incomplete or unseen sequences
hallucination_tests = ["The quick brown", "I am learning", "Deep learning"]
for seq in hallucination_tests:
    print(f"Input: {seq} \nHallucinated: {generate_sequence_with_sampling(seq)}\n")
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.8756 - loss: 1.8458
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - accuracy: 0.9997 - loss: 0.0056
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - accuracy: 0.9994 - loss: 0.0085
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9993 - loss: 0.0080
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9997 - loss: 0.0025
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.9987 - loss: 0.0099
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.9993 - loss: 0.0055
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.9997 - loss: 0.0030
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.9984 - loss: 0.0097
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.9987 - loss: 0.0084
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9989 - loss: 0.0063
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.9981 - loss: 0.0087
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.9984 - loss: 0.0066
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9961 - loss: 0.0103
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.9983 - loss: 0.0035
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9987 - loss: 0.0015
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 1.0000 - loss: 4.8080e-04
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 1.0000 - loss: 3.6020e-04
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 1.0000 - loss: 1.4983e-04
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 1.0000 - loss: 1.8063e-04
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 1.0000 - loss: 2.5393e-04
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 1.0000 - loss: 5.0987e-05
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 1.0000 - loss: 6.3743e-05
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 1.0000 - loss: 1.6530e-04
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 1.0000 - loss: 9.1202e-05
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 3.8202e-05
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 5.5851e-05
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 1.0000 - loss: 2.6744e-05
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 1.0000 - loss: 3.2888e-05
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 1.0000 - loss: 2.1829e-05
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 1.0000 - loss: 3.0322e-05
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 1.0000 - loss: 3.6227e-05
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 1.0000 - loss: 2.2274e-05
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 1.0000 - loss: 1.4034e-05
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 1.0000 - loss: 3.3335e-05
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 1.0000 - loss: 2.8730e-05
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 1.0000 - loss: 1.6270e-05
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 1.0000 - loss: 4.5362e-05
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 1.0000 - loss: 1.1758e-05
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 1.0000 - loss: 1.1282e-05
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 1.0000 - loss: 4.5265e-05
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - accuracy: 1.0000 - loss: 2.3501e-05
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 1.0000 - loss: 1.2686e-05
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 1.6159e-05
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 1.0000 - loss: 1.2628e-05
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 1.0000 - loss: 1.0888e-05
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - accuracy: 1.0000 - loss: 9.2595e-06
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 1.0000 - loss: 1.4016e-05
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 1.0000 - loss: 2.4240e-05
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 1.0000 - loss: 1.0055e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Generated Sequence: The quick brown fox
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Input: The quick brown fox jumped over the lazy dog
# Generated: The quick brown fox jumped over the lazy dog
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Input: I am learning natural language processing
# Generated: I am learning natural language processing
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Input: Artificial intelligence is transforming industries
# Generated: Artificial intelligence is transforming industries
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Input: The quick brown
# Hallucinated: The quick brown
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Input: I am learning
# Hallucinated: I am learning
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Input: Deep learning
# Hallucinated: Deep learning

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import random

# Step 1: Generate Synthetic Data (Memorization and Hallucination)
# Generate some sentences
sentences = [
    "The quick brown fox jumped over the lazy dog",
    "I am learning natural language processing",
    "Artificial intelligence is transforming industries",
    "Deep learning is revolutionizing AI applications",
    "Natural language processing is a field of AI",
    "Machine learning models can analyze large datasets",
    "AI systems are shaping the future of technology",
    "The cat sat on the mat",
    "The dog barked at the stranger",
    "We are building smarter AI systems"
]

# Augment data with variations and noise
def generate_synthetic_data(sentences, num_samples=1000):
    data = []
    for _ in range(num_samples):
        sentence = random.choice(sentences)
        # Introduce random hallucination or noise
        if random.random() > 0.8:  # 20% chance of hallucination
            hallucination = random.choices(sentence.split(), k=random.randint(3, 5))
            data.append(" ".join(hallucination))
        else:
            data.append(sentence)
    return data

synthetic_data = generate_synthetic_data(sentences)

# Step 2: Preprocess Data
# Tokenize the data
tokenizer = Tokenizer()
tokenizer.fit_on_texts(synthetic_data)
vocab_size = len(tokenizer.word_index) + 1  # Adding 1 for padding token

# Convert to sequences
sequences = tokenizer.texts_to_sequences(synthetic_data)

# Pad sequences to ensure uniform length
max_sequence_len = max(len(seq) for seq in sequences)
sequences = pad_sequences(sequences, maxlen=max_sequence_len, padding="post")

# Create predictors (X) and labels (y)
X, y = sequences[:, :-1], sequences[:, -1]
y = np.eye(vocab_size)[y]

# Step 3: Build the LSTM Model with more complexity
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=50, input_length=max_sequence_len - 1),
    LSTM(300, return_sequences=False),  # Increased LSTM units
    Dense(150, activation="relu"),  # Increased units in Dense layer
    Dense(vocab_size, activation="softmax")  # Output layer
])

model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Step 4: Train the Model
model.fit(X, y, epochs=100, batch_size=32, verbose=1)  # Increased epochs for better learning

# Step 5: Generate Sequences with Sampling (Increase temperature for randomness)
def generate_sequence_with_sampling(seed_text, next_words=20, temperature=1.2):  # Increased temperature
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len - 1, padding="post")

        # Predict probabilities
        predictions = model.predict(token_list)[0]

        # Adjust probabilities based on temperature
        predictions = np.asarray(predictions).astype("float64")
        predictions = np.log(predictions + 1e-7) / temperature
        predictions = np.exp(predictions) / np.sum(np.exp(predictions))  # Softmax

        # Sample from the predicted distribution
        predicted = np.random.choice(range(vocab_size), p=predictions)

        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted:
                output_word = word
                break

        seed_text += " " + output_word

    return seed_text

# Example Usage with Sampling (increased next_words for longer output):
seed_text = "The quick brown fox"
generated_sequence = generate_sequence_with_sampling(seed_text, next_words=20, temperature=1.2)
print("Generated Sequence:", generated_sequence)

# Evaluate memorization by providing common sequences
test_sequences = [
    "The quick brown fox jumped over the lazy dog",
    "I am learning natural language processing",
    "Artificial intelligence is transforming industries"
]

for seq in test_sequences:
    print(f"Input: {seq} \nGenerated: {generate_sequence_with_sampling(seq, next_words=20, temperature=1.2)}\n")

# Evaluate hallucination by providing incomplete or unseen sequences
hallucination_tests = [
    "The quick brown",
    "I am learning",
    "Deep learning"
]

for seq in hallucination_tests:
    print(f"Input: {seq} \nHallucinated: {generate_sequence_with_sampling(seq, next_words=20, temperature=1.2)}\n")
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.7896 - loss: 2.5053
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9518 - loss: 0.0758
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 1.0000 - loss: 4.2406e-04
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 3.0114e-04
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 1.0000 - loss: 2.7189e-04
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 1.6656e-04
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 1.0000 - loss: 1.1750e-04
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 1.0000 - loss: 7.9964e-05
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 1.0000 - loss: 5.0473e-05
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 5.2462e-05
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 5.9977e-05
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 4.1271e-05
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 3.0135e-05
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 1.0000 - loss: 3.8153e-05
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 1.0000 - loss: 2.0342e-05
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 1.0000 - loss: 1.9781e-05
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 1.0000 - loss: 1.4963e-05
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 1.0000 - loss: 1.2647e-05
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 1.6940e-05
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 1.0000 - loss: 1.7837e-05
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 1.0000 - loss: 1.5373e-05
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 1.2900e-05
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 1.0000 - loss: 1.0749e-05
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - accuracy: 1.0000 - loss: 9.2453e-06
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 1.0000 - loss: 7.4854e-06
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 1.0000 - loss: 6.7630e-06
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 7.2912e-06
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 9.5767e-06
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 1.0000 - loss: 6.1079e-06
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 1.0000 - loss: 6.4062e-06
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 1.0000 - loss: 6.5889e-06
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 1.0000 - loss: 6.0812e-06
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 6.7157e-06
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 3.0915e-06
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 1.0000 - loss: 4.8544e-06
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 5.1892e-06
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 1.0000 - loss: 4.0731e-06
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 1.0000 - loss: 3.2255e-06
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 1.0000 - loss: 3.4876e-06
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 2.2018e-06
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 1.0000 - loss: 2.9656e-06
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 1.9674e-06
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 1.0000 - loss: 2.6216e-06
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 1.0000 - loss: 3.1491e-06
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 1.0000 - loss: 2.4848e-06
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 2.9949e-06
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 2.1084e-06
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 1.0000 - loss: 1.6379e-06
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 1.8216e-06
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 2.4496e-06
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 1.0000 - loss: 1.7299e-06
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 1.0000 - loss: 1.5967e-06
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 1.0000 - loss: 1.7001e-06
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 1.5105e-06
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 1.0000 - loss: 1.1883e-06
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 1.0000 - loss: 2.6234e-06
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 1.0000 - loss: 1.5088e-06
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 1.0000 - loss: 1.4153e-06
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 1.0000 - loss: 1.3265e-06
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 1.0000 - loss: 1.5265e-06
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 1.0000 - loss: 1.0689e-06
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 1.0000 - loss: 9.8604e-07
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 1.0000 - loss: 1.0723e-06
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 1.0254e-06
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 1.0000 - loss: 1.2415e-06
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 1.0000 - loss: 7.8457e-07
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 1.0000 - loss: 1.0662e-06
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 1.0000 - loss: 1.4969e-06
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 1.3575e-06
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 8.9363e-07
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 1.0000 - loss: 5.9619e-07
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 1.0000 - loss: 9.2470e-07
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 1.0000 - loss: 8.3215e-07
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 1.0000 - loss: 7.0957e-07
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 1.0699e-06
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 6.9236e-07
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 1.0000 - loss: 7.4982e-07
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 1.0000 - loss: 6.9295e-07
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 1.0000 - loss: 7.3153e-07
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 1.0000 - loss: 7.4959e-07
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 1.0000 - loss: 5.5600e-07
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 9.7921e-07
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 4.5157e-07
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 7.9168e-07
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 1.0000 - loss: 5.7896e-07
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 5.0454e-07
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 4.1445e-07
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 1.0000 - loss: 5.1200e-07
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 1.0000 - loss: 5.3536e-07
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 6.5247e-07
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 4.5922e-07
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 2.9815e-07
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 1.0000 - loss: 5.8380e-07
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 7.3417e-07
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 1.0000 - loss: 4.7468e-07
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 1.0000 - loss: 6.0456e-07
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 1.0000 - loss: 2.9406e-07
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 1.0000 - loss: 4.3475e-07
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 1.0000 - loss: 3.2636e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Generated Sequence: The quick brown fox
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Input: The quick brown fox jumped over the lazy dog
# Generated: The quick brown fox jumped over the lazy dog dog dog dog dog dog
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Input: I am learning natural language processing
# Generated: I am learning natural language processing
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Input: Artificial intelligence is transforming industries
# Generated: Artificial intelligence is transforming industries
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Input: The quick brown
# Hallucinated: The quick brown
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Input: I am learning
# Hallucinated: I am learning
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Input: Deep learning
# Hallucinated: Deep learning
